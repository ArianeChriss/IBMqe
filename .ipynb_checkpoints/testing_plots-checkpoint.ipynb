# %%
# Useful additional packages
import qiskit
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.tools.visualization import plot_histogram
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer

from qiskit.visualization import plot_state_city, plot_bloch_multivector
from qiskit.visualization import plot_state_paulivec, plot_state_hinton
from qiskit.visualization import plot_state_qsphere
from qiskit.visualization import plot_bloch_vector

q = QuantumRegister(2)
c = ClassicalRegister(2)

# quantum circuit to make a Bell state 
bell = QuantumCircuit(q,c)
bell.h(q[0])
bell.cx(q[0],q[1])

meas = QuantumCircuit(q,c)
meas.measure(q, c)
print(meas)
plot_bloch_vector(meas)


# execute the quantum circuit 
backend = BasicAer.get_backend('qasm_simulator') # the device to run on
circ = bell+meas
result = execute(circ, backend, shots=1000).result()
counts  = result.get_counts(circ)
# print(counts)

# plot_histogram(counts)

# Execute 2 qubit Bell state again
second_result = execute(circ, backend, shots=1000).result()
second_counts  = second_result.get_counts(circ)
# Plot results with legend
legend = ['First execution', 'Second execution']
plot_histogram([counts, second_counts], legend=legend)

# execute the quantum circuit 
backend = BasicAer.get_backend('statevector_simulator') # the device to run on
result = execute(bell, backend).result()
psi  = result.get_statevector(bell)

plot_state_city(psi)
plot_state_qsphere(psi)
# Out:
#          ┌─┐
# q1_0: |0>┤M├───
#          └╥┘┌─┐
# q1_1: |0>─╫─┤M├
#           ║ └╥┘
#  c1_0: 0 ═╩══╬═
#              ║
#  c1_1: 0 ════╩═
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-c96c00b09550> in <module>
#      29 meas.measure(q, c)
#      30 print(meas)
# ---> 31 plot_bloch_vector(meas)
#      32
#      33
#
# ~\Anaconda3\lib\site-packages\qiskit\visualization\state_visualization.py in plot_bloch_vector(bloch, title, ax, figsize)
#     152     B = Bloch(axes=ax)
#     153     B.add_vectors(bloch)
# --> 154     B.render(title=title)
#     155     if ax is None:
#     156         fig = B.fig
#
# ~\Anaconda3\lib\site-packages\qiskit\visualization\bloch.py in render(self, title)
#     416         self.plot_back()
#     417         self.plot_points()
# --> 418         self.plot_vectors()
#     419         self.plot_front()
#     420         self.plot_axes_labels()
#
# ~\Anaconda3\lib\site-packages\qiskit\visualization\bloch.py in plot_vectors(self)
#     504         for k in range(len(self.vectors)):
#     505
# --> 506             xs3d = self.vectors[k][1] * np.array([0, 1])
#     507             ys3d = -self.vectors[k][0] * np.array([0, 1])
#     508             zs3d = self.vectors[k][2] * np.array([0, 1])
#
# ValueError: operands could not be broadcast together with shapes (3,) (2,)

# %%
plot_bloch_vector([0, 1, 0])
